# %% [markdown]
# # K-means
# https://scikit-learn.org/stable/
# <img src="https://mofanpy.com/static/results/sklearn/2_1_1.png">
#
# ## K-means是一種分群方法，為非監督式學習
#
# ### 1. 設定n群
# ### 2. K-means隨機給予n個群心
# ### 3. 每個點用距離公式計算並分類給最近的群
# ### 4. 用每一群的點重新計算群心
# ### 5. 重複3、4步驟直到收斂

# %%
# %matplotlib inline

import random
import numpy as np
from sklearn import cluster, metrics
import matplotlib.pyplot as plt

feature = np.array([2, 2])
for i in range(3000):
    if i%3 == 0:
        x = 3 + random.normalvariate(0, 1.2)
        y = 3 + random.normalvariate(0, 1.2)
        feature = np.vstack((feature, [x, y]))
        plt.scatter(x, y , color='b', s=2)
    elif i%3 == 1:
        x = 7 + random.normalvariate(0, 1)
        y = 7 + random.normalvariate(0, 1)
        feature = np.vstack((feature, [x, y]))
        plt.scatter(x, y , color='r', s=2)
    else:
        x = 8 + random.normalvariate(0, 0.7)
        y = 2 + random.normalvariate(0, 0.7)
        feature = np.vstack((feature, [x, y]))
        plt.scatter(x, y , color='g', s=2)
feature = feature[1:]

plt.xlim(0, 10)
plt.ylim(0, 10)
plt.show()

# %%
feature
# Out:
# array([[2.70167846, 3.94684428],
#        [6.41900242, 7.0540904 ],
#        [8.55879813, 2.5796263 ],
#        ...,
#        [2.33151183, 2.64555021],
#        [8.09981743, 8.72220637],
#        [7.75808554, 2.53332487]])

# %% [markdown]
# ### K-means官方文件
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
# 迴圈
silhouette_avgs = []
ks = range(2, 7)
for k in ks:
    kmeans_fit = cluster.KMeans(n_clusters = k).fit(feature)
    cluster_labels = kmeans_fit.labels_
    silhouette_avg = metrics.silhouette_score(feature, cluster_labels) # -1 ~ 1
    silhouette_avgs.append(silhouette_avg)

# 作圖並印出 k = 2 到 10 的績效
plt.bar(ks, silhouette_avgs)
plt.show()
print(silhouette_avgs)
# Out:
# [0.4722471922502418, 0.6468821933058657, 0.5516902314466203, 0.44669479806477436, 0.4407756363832297]

# %%
print(cluster_labels)
# Out:
# [4 5 0 ... 1 5 0]

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/0DGtyMBOZ-c" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# 出處: https://chih-sheng-huang821.medium.com/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92-%E9%9B%86%E7%BE%A4%E5%88%86%E6%9E%90-k-means-clustering-e608a7fe1b43
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/0DGtyMBOZ-c" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # KNN(k nearest neighbors)
# ## KNN可以做分類或回歸，為監督式學習
# ### 1. 設定k值
# ### 2. 計算距離公式找出k個最相近的特徵
# ### 3. 分類: k個特徵投票、回歸: 平均k個特徵
# <img src="https://ww2.mathworks.cn/matlabcentral/mlc-downloads/downloads/03faee64-e85e-4ea0-a2b4-e5964949e2d1/d99b9a4d-618c-45f0-86d1-388bdf852c1d/images/screenshot.gif">

# %% [markdown]
# ### 蒐集資料
# python MLGame.py -i ml_play_template.py -f 200 -r arkanoid NORMAL 3

# %%
import pickle
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import  classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedShuffleSplit

#試取資料
file = open("/Users/peggy/Documents/109-2(2-2)/Introduction to machine learning and its application to gaming/MLGame/games/arkanoid/log/second_EASY1_1.pickle", "rb")
data = pickle.load(file)
file.close()
type(data['ml'])
# Out:
# dict

# %%
game_info = data['ml']['scene_info']
game_command = data['ml']['command']
print(game_info)
print(game_command)
# Out:
# [{'frame': 0, 'status': 'GAME_ALIVE', 'ball': (93, 395), 'platform': (75, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 1, 'status': 'GAME_ALIVE', 'ball': (93, 395), 'platform': (75, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 2, 'status': 'GAME_ALIVE', 'ball': (86, 388), 'platform': (70, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 3, 'status': 'GAME_ALIVE', 'ball': (79, 381), 'platform': (75, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 4, 'status': 'GAME_ALIVE', 'ball': (72, 374), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 5, 'status': 'GAME_ALIVE', 'ball': (65, 367), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 6, 'status': 'GAME_ALIVE', 'ball': (58, 360), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 7, 'status': 'GAME_ALIVE', 'ball': (51, 353), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 8, 'status': 'GAME_ALIVE', 'ball': (44, 346), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 9, 'status': 'GAME_ALIVE', 'ball': (37, 339), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 10, 'status': 'GAME_ALIVE', 'ball': (30, 332), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 11, 'status': 'GAME_ALIVE', 'ball': (23, 325), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 12, 'status': 'GAME_ALIVE', 'ball': (16, 318), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 13, 'status': 'GAME_ALIVE', 'ball': (9, 311), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 14, 'status': 'GAME_ALIVE', 'ball': (2, 304), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 15, 'status': 'GAME_ALIVE', 'ball': (0, 297), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 16, 'status': 'GAME_ALIVE', 'ball': (7, 290), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 17, 'status': 'GAME_ALIVE', 'ball': (14, 283), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 18, 'status': 'GAME_ALIVE', 'ball': (21, 276), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 19, 'status': 'GAME_ALIVE', 'ball': (28, 269), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 20, 'status': 'GAME_ALIVE', 'ball': (35, 262), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 21, 'status': 'GAME_ALIVE', 'ball': (42, 255), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 22, 'status': 'GAME_ALIVE', 'ball': (49, 248), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 23, 'status': 'GAME_ALIVE', 'ball': (56, 241), 'platform': (80, 400), 'bricks': [(35, 50), (60, 50), (85, 50), (110, 50), (135, 50)], 'hard_bricks': []}, {'frame': 24, 'status': 'GAME_ALIVE', 'ball': (63, 234), 'platform': (80, 400 ...
# ['SERVE_TO_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'NONE', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_RIGHT', 'MOVE_LEFT', 'MOVE_LEFT', 'MOVE_LEFT', 'NONE', 'NONE', 'MOVE_RIGHT', 'MOVE_RIGHT', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT', 'MOVE_RIGHT',  ...

# %%
for i in range(2, 10):#EASY1
    path = "/Users/peggy/Documents/109-2(2-2)/Introduction to machine learning and its application to gaming/MLGame/games/arkanoid/log/second_EASY1_" + str(i) + ".pickle"
    file = open(path, "rb")
    data = pickle.load(file)
    game_info = game_info + data['ml']['scene_info']
    game_command = game_command + data['ml']['command']
    file.close()
for i in range(1, 10):#EASY2
    path = "/Users/peggy/Documents/109-2(2-2)/Introduction to machine learning and its application to gaming/MLGame/games/arkanoid/log/second_EASY2_" + str(i) + ".pickle"
    file = open(path, "rb")
    data = pickle.load(file)
    game_info = game_info + data['ml']['scene_info']
    game_command = game_command + data['ml']['command']
    file.close()
for i in range(1, 10):#EASY3
    path = "/Users/peggy/Documents/109-2(2-2)/Introduction to machine learning and its application to gaming/MLGame/games/arkanoid/log/second_EASY3_" + str(i) + ".pickle"
    file = open(path, "rb")
    data = pickle.load(file)
    game_info = game_info + data['ml']['scene_info']
    game_command = game_command + data['ml']['command']
    file.close()
for i in range(1, 21):#NORMAL1
    path = "/Users/peggy/Documents/109-2(2-2)/Introduction to machine learning and its application to gaming/MLGame/games/arkanoid/log/second_NORM1_" + str(i) + ".pickle"
    file = open(path, "rb")
    data = pickle.load(file)
    game_info = game_info + data['ml']['scene_info']
    game_command = game_command + data['ml']['command']
    file.close()
for i in range(1, 21):#NORMAL2
    path = "/Users/peggy/Documents/109-2(2-2)/Introduction to machine learning and its application to gaming/MLGame/games/arkanoid/log/second_NORM2_" + str(i) + ".pickle"
    file = open(path, "rb")
    data = pickle.load(file)
    game_info = game_info + data['ml']['scene_info']
    game_command = game_command + data['ml']['command']
    file.close()
for i in range(1, 21):#NORMAL3
    path = "/Users/peggy/Documents/109-2(2-2)/Introduction to machine learning and its application to gaming/MLGame/games/arkanoid/log/second_NORM3_" + str(i) + ".pickle"
    file = open(path, "rb")
    data = pickle.load(file)
    game_info = game_info + data['ml']['scene_info']
    game_command = game_command + data['ml']['command']
    file.close()
    
print(len(game_info))
print(len(game_command))
# Out:
# 169388
# 169388

# %% [markdown]
# ### 特徵整理

# %%
g = game_info[1]
#gprev = game_info[i - 1]
#x_velo = g['ball'][0] - gprev['ball'][0]
#y_velo = g['ball'][1] - gprev['ball'][1]
    
feature = np.array([g['ball'][0], g['ball'][1], g['platform'][0], 0, 0, 0])#x軸速率，沒有y軸   球上升還下降   板子往左還往右還不動
print(feature)

print(game_command[1])
game_command[1] = 0
# Out:
# [ 93 395  75   0   0   0]
# MOVE_LEFT

# %%
for i in range(2, len(game_info) - 1):
    g = game_info[i]
    gprev = game_info[i - 1]
    x_velo = g['ball'][0] - gprev['ball'][0]
    y_velo = g['ball'][1] - gprev['ball'][1]
    plat_velo = g['platform'][0] - gprev['platform'][0]
    feature = np.vstack((feature, [g['ball'][0], g['ball'][1], g['platform'][0], x_velo, y_velo, plat_velo]))#要加其他feature 可加板子跟球是不是同向
    if game_command[i] == "NONE": game_command[i] = 0
    elif game_command[i] == "MOVE_LEFT": game_command[i] = 1
    else: game_command[i] = 2
    
answer = np.array(game_command[1:-1])#answer跟板子有關

print(feature)
print(feature.shape)
print(answer)
print(answer.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-c22df41ebefb> in <module>
#       5     y_velo = g['ball'][1] - gprev['ball'][1]
#       6     plat_velo = g['platform'][0] - gprev['platform'][0]
# ----> 7     feature = np.vstack((feature, [g['ball'][0], g['ball'][1], g['platform'][0], x_velo, y_velo, plat_velo]))#要加其他feature 可加板子跟球是不是同向
#       8     if game_command[i] == "NONE": game_command[i] = 0
#       9     elif game_command[i] == "MOVE_LEFT": game_command[i] = 1
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### KNN官方文件
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# ### 交叉驗證
# https://chih-sheng-huang821.medium.com/%E4%BA%A4%E5%8F%89%E9%A9%97%E8%AD%89-cross-validation-cv-3b2c714b18db

# %%
#資料劃分
x_train, x_test, y_train, y_test = train_test_split(feature, answer, test_size=0.2, random_state=9)#從前面丟feature近來
#參數區間
param_grid = {'n_neighbors':[1, 2, 3]}#板子 左 右 不動
#交叉驗證 
cv = StratifiedShuffleSplit(n_splits=2, test_size=0.2, random_state=12)
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=cv, verbose=10, n_jobs=-1) #n_jobs為平行運算的數量
grid.fit(x_train, y_train)
grid_predictions = grid.predict(x_test)

#儲存
file = open('second_arkanoid_knn_model.pickle', 'wb')
pickle.dump(grid, file)
file.close()
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   6 | elapsed:    2.1s remaining:    4.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    2.2s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:    2.2s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    2.2s finished

# %% [markdown]
# ### f1-score
# https://medium.com/nlp-tsupei/precision-recall-f1-score%E7%B0%A1%E5%96%AE%E4%BB%8B%E7%B4%B9-f87baa82a47

# %%
#最佳參數
print(grid.best_params_)
#預測結果
#print(grid_predictions)
#混淆矩陣
print(confusion_matrix(y_test, grid_predictions))
#分類結果
print(classification_report(y_test, grid_predictions))
# Out:
# {'n_neighbors': 1}
# [[3347   18   11]
#  [  12 1620    9]
#  [  11   16 1971]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3376
#            1       0.98      0.99      0.98      1641
#            2       0.99      0.99      0.99      1998
#
#     accuracy                           0.99      7015
#    macro avg       0.99      0.99      0.99      7015
# weighted avg       0.99      0.99      0.99      7015

# %% [markdown]
# ### 執行遊戲
# python MLGame.py -i knn.py -f 50 arkanoid NORMAL 3
